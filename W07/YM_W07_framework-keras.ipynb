# %% [markdown]
# # **Week7. Assignment (Keras)**
# 13기 이유민

# %% [markdown]
# # **0. Setting**

# %%
cd/content/drive/My Drive/tobigs
# Out:
# /content/drive/My Drive/tobigs

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **1. Data & Preprocessing**

# %%
import numpy as np
import pandas as pd
import keras

sample_submission = pd.read_csv("sample_submission.csv")
train = pd.read_csv("train_df.csv")
test = pd.read_csv("test_df.csv")

print(train.shape, test.shape)
# Out:
# (42000, 785) (18000, 785)

# %%
train.head() # 784 픽셀 확인
# Out:
#    label  pixel0  pixel1  pixel2  ...  pixel780  pixel781  pixel782  pixel783
# 0      7       0       0       0  ...         0         0         0         0
# 1      8       0       0       0  ...         0         0         0         0
# 2      7       0       0       0  ...         0         0         0         0
# 3      6       0       0       0  ...         0         0         0         0
# 4      5       0       0       0  ...         0         0         0         0
#
# [5 rows x 785 columns]

# %%
# X, y 지정
X = train.iloc[:,1:].values
X = X.reshape(X.shape[0], 28, 28,1)

y = train.iloc[:,0].values
y = keras.utils.to_categorical(y,10) 

# X_test 지정
X_test = test.iloc[:,1:].values
X_test = X_test.reshape(X_test.shape[0], 28, 28,1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=2018)

print(x_train.shape, x_val.shape, y_train.shape, y_val.shape)
# Out:
# (33600, 28, 28, 1) (8400, 28, 28, 1) (33600, 10) (8400, 10)

# %%
import matplotlib.pyplot as plt

plt.imshow(x_train[1].reshape(28, 28), cmap="gray")

# %% [markdown]
# ## **3. Define Model**

# %%
# 구글 참고
from keras.preprocessing.image import ImageDataGenerator

imagegen = ImageDataGenerator(
    rescale=1./255.,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip = False
)

valid_datagen = ImageDataGenerator(rescale=1./255)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:348: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, which overrides setting of `featurewise_center`.
#   warnings.warn('This ImageDataGenerator specifies '

# %%
initial_learningrate=1e-3

def lr_decay(epoch):
    return initial_learningrate * 0.99 ** epoch

# %%
import tensorflow as tf
num_classes = 10

model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, (3,3), padding='same', input_shape=(28, 28, 1), kernel_initializer='he_normal'),
  # weight initialization
  tf.keras.layers.Activation('relu'),
  tf.keras.layers.Conv2D(64, (3,3), padding='same'), 
  tf.keras.layers.MaxPooling2D(3, 3),
  tf.keras.layers.Activation('relu'),
  tf.keras.layers.Dropout(0.2),  # regularization / overfitting 방지

  tf.keras.layers.Conv2D(256, (3,3), padding='same'),
  tf.keras.layers.BatchNormalization(gamma_initializer="normal"),
  tf.keras.layers.Activation('relu'),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Dropout(0.2),  # regularization

  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(256),
  tf.keras.layers.Activation('relu'),
  tf.keras.layers.BatchNormalization(momentum=0.2, gamma_initializer='uniform'),   # batch normalization
  tf.keras.layers.Dense(num_classes, activation="softmax"),   # output shape : (10,1)
])

# %%
class myAccuracy(tf.keras.metrics.Accuracy):
    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.argmax(y_true,1)
        y_pred = tf.argmax(y_pred,1)
        return super(myAccuracy,self).update_state(y_true,y_pred,sample_weight)

# %%
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=[myAccuracy()])
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_15 (Conv2D)           (None, 28, 28, 32)        320
# _________________________________________________________________
# activation_9 (Activation)    (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 9, 9, 64)          0
# _________________________________________________________________
# activation_10 (Activation)   (None, 9, 9, 64)          0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 9, 9, 64)          0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 9, 9, 256)         147712
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 9, 9, 256)         1024
# _________________________________________________________________
# activation_11 (Activation)   (None, 9, 9, 256)         0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               1048832
# _________________________________________________________________
# activation_12 (Activation)   (None, 256)               0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_22 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 1,219,978
# Trainable params: 1,218,954
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
history = model.fit_generator(
      imagegen.flow(x_train,y_train, batch_size=10),
      steps_per_epoch=100,
      epochs=100,
      validation_data=valid_datagen.flow(x_val,y_val),
      validation_steps=50,  
      verbose=2)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:716: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:724: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 1/100
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:716: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:724: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 1/100
# 100/100 - 4s - loss: 2.0139 - accuracy: 0.3890 - val_loss: 1.6953 - val_accuracy: 0.4638
# Epoch 2/100
# Epoch 1/100
# 100/100 - 1s - loss: 1.1822 - accuracy: 0.6590 - val_loss: 0.6258 - val_accuracy: 0.8619
# Epoch 3/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.8387 - accuracy: 0.7430 - val_loss: 0.2316 - val_accuracy: 0.9550
# Epoch 4/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.6251 - accuracy: 0.8160 - val_loss: 0.1481 - val_accuracy: 0.9588
# Epoch 5/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.5167 - accuracy: 0.8400 - val_loss: 0.1233 - val_accuracy: 0.9619
# Epoch 6/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.4615 - accuracy: 0.8610 - val_loss: 0.1121 - val_accuracy: 0.9688
# Epoch 7/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.4180 - accuracy: 0.8820 - val_loss: 0.0926 - val_accuracy: 0.9688
# Epoch 8/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.3698 - accuracy: 0.8890 - val_loss: 0.0826 - val_accuracy: 0.9744
# Epoch 9/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.3644 - accuracy: 0.8790 - val_loss: 0.1320 - val_accuracy: 0.9606
# Epoch 10/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.3501 - accuracy: 0.8880 - val_loss: 0.1315 - val_accuracy: 0.9606
# Epoch 11/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.3223 - accuracy: 0.8950 - val_loss: 0.1143 - val_accuracy: 0.9631
# Epoch 12/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.2890 - accuracy: 0.9120 - val_loss: 0.0662 - val_accuracy: 0.9837
# Epoch 13/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.3156 - accuracy: 0.9140 - val_loss: 0.0658 - val_accuracy: 0.9856
# Epoch 14/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.2387 - accuracy: 0.9280 - val_loss: 0.0761 - val_accuracy: 0.9819
# Epoch 15/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.3204 - accuracy: 0.8990 - val_loss: 0.0767 - val_accuracy: 0.9819
# Epoch 16/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.2551 - accuracy: 0.9180 - val_loss: 0.0832 - val_accuracy: 0.9794
# Epoch 17/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.2752 - accuracy: 0.9040 - val_loss: 0.0944 - val_accuracy: 0.9762
# Epoch 18/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.2414 - accuracy: 0.9170 - val_loss: 0.0801 - val_accuracy: 0.9794
# Epoch 19/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.2134 - accuracy: 0.9270 - val_loss: 0.0741 - val_accuracy: 0.9806
# Epoch 20/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.2303 - accuracy: 0.9280 - val_loss: 0.0533 - val_accuracy: 0.9856
# Epoch 21/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.2110 - accuracy: 0.9300 - val_loss: 0.1192 - val_accuracy: 0.9669
# Epoch 22/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.2196 - accuracy: 0.9300 - val_loss: 0.0535 - val_accuracy: 0.9856
# Epoch 23/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.2241 - accuracy: 0.9350 - val_loss: 0.0825 - val_accuracy: 0.9794
# Epoch 24/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1910 - accuracy: 0.9410 - val_loss: 0.0566 - val_accuracy: 0.9856
# Epoch 25/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.2281 - accuracy: 0.9300 - val_loss: 0.0607 - val_accuracy: 0.9831
# Epoch 26/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.2245 - accuracy: 0.9330 - val_loss: 0.0720 - val_accuracy: 0.9781
# Epoch 27/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.2204 - accuracy: 0.9290 - val_loss: 0.0514 - val_accuracy: 0.9862
# Epoch 28/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.2313 - accuracy: 0.9360 - val_loss: 0.0545 - val_accuracy: 0.9819
# Epoch 29/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.2014 - accuracy: 0.9470 - val_loss: 0.0483 - val_accuracy: 0.9869
# Epoch 30/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1762 - accuracy: 0.9400 - val_loss: 0.1097 - val_accuracy: 0.9712
# Epoch 31/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1924 - accuracy: 0.9390 - val_loss: 0.0736 - val_accuracy: 0.9825
# Epoch 32/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1949 - accuracy: 0.9280 - val_loss: 0.0565 - val_accuracy: 0.9819
# Epoch 33/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.2092 - accuracy: 0.9270 - val_loss: 0.0557 - val_accuracy: 0.9862
# Epoch 34/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1749 - accuracy: 0.9400 - val_loss: 0.0549 - val_accuracy: 0.9856
# Epoch 35/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1698 - accuracy: 0.9460 - val_loss: 0.0618 - val_accuracy: 0.9856
# Epoch 36/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.2012 - accuracy: 0.9380 - val_loss: 0.0719 - val_accuracy: 0.9787
# Epoch 37/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1944 - accuracy: 0.9440 - val_loss: 0.0585 - val_accuracy: 0.9837
# Epoch 38/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1922 - accuracy: 0.9450 - val_loss: 0.0492 - val_accuracy: 0.9887
# Epoch 39/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.2122 - accuracy: 0.9350 - val_loss: 0.0522 - val_accuracy: 0.9850
# Epoch 40/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1860 - accuracy: 0.9440 - val_loss: 0.0560 - val_accuracy: 0.9881
# Epoch 41/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1448 - accuracy: 0.9490 - val_loss: 0.0591 - val_accuracy: 0.9862
# Epoch 42/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1984 - accuracy: 0.9360 - val_loss: 0.0528 - val_accuracy: 0.9894
# Epoch 43/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1781 - accuracy: 0.9420 - val_loss: 0.0507 - val_accuracy: 0.9887
# Epoch 44/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1959 - accuracy: 0.9400 - val_loss: 0.0406 - val_accuracy: 0.9887
# Epoch 45/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1806 - accuracy: 0.9390 - val_loss: 0.0452 - val_accuracy: 0.9894
# Epoch 46/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1626 - accuracy: 0.9420 - val_loss: 0.0459 - val_accuracy: 0.9869
# Epoch 47/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1615 - accuracy: 0.9530 - val_loss: 0.0441 - val_accuracy: 0.9887
# Epoch 48/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1738 - accuracy: 0.9460 - val_loss: 0.0395 - val_accuracy: 0.9862
# Epoch 49/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1391 - accuracy: 0.9540 - val_loss: 0.0439 - val_accuracy: 0.9869
# Epoch 50/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1869 - accuracy: 0.9430 - val_loss: 0.0537 - val_accuracy: 0.9850
# Epoch 51/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1880 - accuracy: 0.9460 - val_loss: 0.0499 - val_accuracy: 0.9844
# Epoch 52/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1992 - accuracy: 0.9310 - val_loss: 0.0378 - val_accuracy: 0.9887
# Epoch 53/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1457 - accuracy: 0.9550 - val_loss: 0.0453 - val_accuracy: 0.9856
# Epoch 54/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1554 - accuracy: 0.9530 - val_loss: 0.0410 - val_accuracy: 0.9881
# Epoch 55/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1814 - accuracy: 0.9510 - val_loss: 0.0493 - val_accuracy: 0.9875
# Epoch 56/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1294 - accuracy: 0.9640 - val_loss: 0.0460 - val_accuracy: 0.9875
# Epoch 57/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1379 - accuracy: 0.9480 - val_loss: 0.0417 - val_accuracy: 0.9862
# Epoch 58/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1415 - accuracy: 0.9580 - val_loss: 0.0518 - val_accuracy: 0.9862
# Epoch 59/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1242 - accuracy: 0.9620 - val_loss: 0.0446 - val_accuracy: 0.9900
# Epoch 60/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1448 - accuracy: 0.9540 - val_loss: 0.0341 - val_accuracy: 0.9912
# Epoch 61/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1454 - accuracy: 0.9580 - val_loss: 0.0624 - val_accuracy: 0.9837
# Epoch 62/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1396 - accuracy: 0.9520 - val_loss: 0.0376 - val_accuracy: 0.9862
# Epoch 63/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1742 - accuracy: 0.9450 - val_loss: 0.0480 - val_accuracy: 0.9831
# Epoch 64/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1276 - accuracy: 0.9560 - val_loss: 0.0547 - val_accuracy: 0.9812
# Epoch 65/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1313 - accuracy: 0.9580 - val_loss: 0.0478 - val_accuracy: 0.9887
# Epoch 66/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1322 - accuracy: 0.9610 - val_loss: 0.0586 - val_accuracy: 0.9837
# Epoch 67/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1045 - accuracy: 0.9690 - val_loss: 0.0571 - val_accuracy: 0.9831
# Epoch 68/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1340 - accuracy: 0.9660 - val_loss: 0.0549 - val_accuracy: 0.9825
# Epoch 69/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1538 - accuracy: 0.9440 - val_loss: 0.0560 - val_accuracy: 0.9850
# Epoch 70/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1366 - accuracy: 0.9600 - val_loss: 0.0577 - val_accuracy: 0.9869
# Epoch 71/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1630 - accuracy: 0.9560 - val_loss: 0.0511 - val_accuracy: 0.9869
# Epoch 72/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1272 - accuracy: 0.9640 - val_loss: 0.0495 - val_accuracy: 0.9825
# Epoch 73/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1336 - accuracy: 0.9570 - val_loss: 0.0364 - val_accuracy: 0.9887
# Epoch 74/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1577 - accuracy: 0.9470 - val_loss: 0.0344 - val_accuracy: 0.9912
# Epoch 75/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1465 - accuracy: 0.9540 - val_loss: 0.0477 - val_accuracy: 0.9875
# Epoch 76/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1488 - accuracy: 0.9520 - val_loss: 0.0514 - val_accuracy: 0.9875
# Epoch 77/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1323 - accuracy: 0.9610 - val_loss: 0.0414 - val_accuracy: 0.9894
# Epoch 78/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1206 - accuracy: 0.9570 - val_loss: 0.0469 - val_accuracy: 0.9862
# Epoch 79/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1543 - accuracy: 0.9480 - val_loss: 0.0461 - val_accuracy: 0.9856
# Epoch 80/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1180 - accuracy: 0.9690 - val_loss: 0.0330 - val_accuracy: 0.9906
# Epoch 81/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1353 - accuracy: 0.9590 - val_loss: 0.0322 - val_accuracy: 0.9900
# Epoch 82/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1331 - accuracy: 0.9610 - val_loss: 0.0563 - val_accuracy: 0.9844
# Epoch 83/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1243 - accuracy: 0.9620 - val_loss: 0.0534 - val_accuracy: 0.9856
# Epoch 84/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1376 - accuracy: 0.9530 - val_loss: 0.0445 - val_accuracy: 0.9906
# Epoch 85/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1183 - accuracy: 0.9670 - val_loss: 0.0392 - val_accuracy: 0.9887
# Epoch 86/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1210 - accuracy: 0.9580 - val_loss: 0.0463 - val_accuracy: 0.9856
# Epoch 87/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1316 - accuracy: 0.9550 - val_loss: 0.0426 - val_accuracy: 0.9894
# Epoch 88/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1036 - accuracy: 0.9670 - val_loss: 0.0533 - val_accuracy: 0.9812
# Epoch 89/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1064 - accuracy: 0.9600 - val_loss: 0.0392 - val_accuracy: 0.9912
# Epoch 90/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1795 - accuracy: 0.9490 - val_loss: 0.0411 - val_accuracy: 0.9875
# Epoch 91/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1330 - accuracy: 0.9620 - val_loss: 0.0476 - val_accuracy: 0.9862
# Epoch 92/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1435 - accuracy: 0.9560 - val_loss: 0.0429 - val_accuracy: 0.9881
# Epoch 93/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1150 - accuracy: 0.9620 - val_loss: 0.0351 - val_accuracy: 0.9906
# Epoch 94/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1454 - accuracy: 0.9570 - val_loss: 0.0336 - val_accuracy: 0.9875
# Epoch 95/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1422 - accuracy: 0.9490 - val_loss: 0.0330 - val_accuracy: 0.9925
# Epoch 96/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1008 - accuracy: 0.9690 - val_loss: 0.0429 - val_accuracy: 0.9912
# Epoch 97/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1099 - accuracy: 0.9710 - val_loss: 0.0429 - val_accuracy: 0.9912
# Epoch 98/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1224 - accuracy: 0.9570 - val_loss: 0.0366 - val_accuracy: 0.9912
# Epoch 99/100
# Epoch 1/100
# 100/100 - 2s - loss: 0.1120 - accuracy: 0.9640 - val_loss: 0.0588 - val_accuracy: 0.9856
# Epoch 100/100
# Epoch 1/100
# 100/100 - 1s - loss: 0.1236 - accuracy: 0.9650 - val_loss: 0.0433 - val_accuracy: 0.9900

# %%
predictions = model.predict_classes(X_test)

# %%
predictions
# Out:
# array([8, 0, 5, ..., 3, 5, 9])

# %%
sample_submission["Category"] = pd.Series(predictions)
sample_submission
# Out:
#           Id  Category
# 0      57808         8
# 1       4960         0
# 2      35755         5
# 3      15543         3
# 4      48968         8
# ...      ...       ...
# 17995  53718         8
# 17996     78         8
# 17997  33373         3
# 17998  36134         5
# 17999  54021         9
#
# [18000 rows x 2 columns]

# %%
#저장
sample_submission.to_csv("radam_submission3.csv", index=False)

# %%
fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'y', label='train loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper left')

acc_ax.plot(history.history['accuracy'], 'b', label='train acc')
acc_ax.plot(history.history['val_accuracy'], 'g', label='val acc')
acc_ax.set_ylabel('accuracy')
acc_ax.legend(loc='upper left')

plt.show()
