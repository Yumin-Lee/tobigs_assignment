# %% [markdown]
# # 과제1. Task1 파일에서 함수 구현

# %%
import numpy as np
from numpy.linalg import inv

# %%
def estimate_beta(x, y):
    beta_hat = np.matmul(np.matmul(inv(np.matmul(x.T, x)), x.T), y)
    #beta hat이 (tr(x)*x)-1 * tr(x)*y 임을 나타내자
    return beta_hat

# %%
#x행렬에 intercept를 추가해야함
x = np.array([ [1, 0, 1],
               [1, 2, 3],
               [1, 3, 8]]) #3x3
y = np.transpose(np.array([1, 3, 7])) #3x1

# %%
x
# Out:
# array([[1, 0, 1],
#        [1, 2, 3],
#        [1, 3, 8]])

# %%
y
# Out:
# array([1, 3, 7])

# %%
estimate_beta(x,y)
# Out:
# array([0.25, 0.25, 0.75])

# %%
#sklearn은 디폴트로 intercept가 fit되므로, 데이터에 intercept가 포함된 경우는 fit_intercept=False로 해야함

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression(fit_intercept=False).fit(x, y)

# %%
reg.coef_
# Out:
# array([0.25, 0.25, 0.75])

# %% [markdown]
# # 과제 2.
# 1) 1주차 과제 데이터로 선형회귀에 필요한 EDA/전처리/인코딩
#  -범주형 변수 인코딩 3개, EDA 3개
#
# 2) hammer price를 target으로 선형회귀분석
#
# 3) 적합된 회귀식에 대해 데이터의 행렬을 통해 beta, mse 구해서 위의 값과 비교
#  - sklearn 사용X, 행렬 통해 값 추출하기

# %% [markdown]
# # 데이터 불러오기 & 전처리

# %%
# #-*- coding: utf-8 -*-

# %%
import pandas as pd
import numpy as np
import csv
import warnings
import seaborn as sns; sns.set
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('Auction_master_train_1.csv', encoding='cp949') #데이터 불러오기

# %%
df.head(25) #데이터 확인
# Out:
#     Auction_key Auction_class Bid_class  Claim_price Appraisal_company  \
# 0          2687            임의        개별   1766037301              정명감정
# 1          2577            임의        일반    152946867               희감정
# 2          2197            임의        개별     11326510              혜림감정
# 3          2642            임의        일반    183581724              신라감정
# 4          1958            강제        일반     45887671              나라감정
# 5          2238            강제        일반    105437195             한마음감정
# 6          1923            임의        일반    137548730            미래새한감정
# 7          2527            임의        일반    506916971              부일감정
# 8          2259            강제        일반     40782876              금정감정
# 9          2666            임의        일반    150000000              연산감정
# 10         2362            임의        개별    500000000              명장감정
# 11         1947            임의        일반     37122950              명장감정
# 12         2298            임의        일반     25000000              문일감정
# 13         2550            임의        일반    135000000              미르감정
# 14         2046            임의        일반    953680000              국제감정
# 15         2678            강제        일반     13848484              드림감정
# 16         2682            임의        일반    149393725              금정감정
# 17         1861            임의        개별   1046685025              대일감정
# 18         2037            임의        일반     42479480            미래새한감정
# 19         2103            임의        일반     30665922             한마음감정
# 20         2254            강제        일반    160000000              혜림감정
# 21         1971            임의        일반     45589041              드림감정
# 22         2491            임의        일반    122134370              문일감정
# 23         2067            강제        일반     19800000              대한감정
# 24         1960            강제        일반    122663013               희감정
#
#          Appraisal_date  Auction_count  Auction_miscarriage_count  \
# 0   2017-07-26 00:00:00              2                          1
# 1   2016-09-12 00:00:00              2                          1
# 2   2016-11-22 00:00:00              3                          2
# 3   2016-12-13 00:00:00              2                          1
# 4   2016-03-07 00:00:00              2                          1
# 5   2017-01-03 00:00:00              2                          1
# 6   2016-01-19 00:00:00              3                          2
# 7   2016-04-28 00:00:00              2                          1
# 8   2016-03-08 00:00:00              2                          1
# 9   2017-03-27 00:00:00              2                          1
# 10  2017-02-22 00:00:00              2                          1
# 11  2016-02-18 00:00:00              2                          1
# 12  2016-09-26 00:00:00              4                          2
# 13  2016-07-24 00:00:00              2                          1
# 14  2016-06-01 00:00:00              1                          0
# 15  2017-06-14 00:00:00              2                          1
# 16  2017-07-04 00:00:00              3                          2
# 17  2015-12-02 00:00:00              2                          1
# 18  2016-05-25 00:00:00              2                          1
# 19  2016-08-02 00:00:00              2                          1
# 20  2016-03-02 00:00:00              1                          0
# 21  2016-03-21 00:00:00              2                          1
# 22  2016-01-26 00:00:00              2                          1
# 23  2016-07-05 00:00:00              2                          1
# 24  2016-03-21 00:00:00              3                          1
#
#     Total_land_gross_area  Total_land_real_area  ...  \
# 0                 12592.0                 37.35  ...
# 1                 42478.1                 18.76  ...
# 2                149683.1                 71.00  ...
# 3                 24405.0                 32.98  ...
# 4                   774.0                 45.18  ...
# 5                  8635.0                 41.39  ...
# 6                  7927.0                 81.77  ...
# 7                331281.0                 92.22  ...
# 8                  1017.0                 66.44  ...
# 9                 27447.2                 78.52  ...
# 10                 1205.8                 18.27  ...
# 11                 5043.0                 37.38  ...
# 12                 8880.0                 31.69  ...
# 13                    0.0                  0.00  ...
# 14                82385.1                 80.62  ...
# 15                41235.0                 53.84  ...
# 16                12133.7                 25.70  ...
# 17                  331.0                  7.59  ...
# 18                  798.0                 41.69  ...
# 19                 1389.0                 39.43  ...
# 20                 2405.0                  5.66  ...
# 21                10145.0                 30.87  ...
# 22                12133.7                 20.60  ...
# 23                17575.3                 39.80  ...
# 24                  247.0                 17.93  ...
#
#                                              Specific  Share_auction_YorN  \
# 0                                                 NaN                   N
# 1                                                 NaN                   N
# 2                                                 NaN                   N
# 3                                                 NaN                   N
# 4                                                 NaN                   N
# 5                                                 NaN                   N
# 6                                                 NaN                   N
# 7                                                 NaN                   N
# 8                                                 NaN                   N
# 9                                                 NaN                   N
# 10                                                NaN                   N
# 11                                                NaN                   N
# 12  공유자 박수미,박종학으로부터 공유자 우선매수신고 있음.공유자가 민사집행법 제140조...                   Y
# 13                                                NaN                   N
# 14                                                NaN                   N
# 15                                                NaN                   N
# 16                                                NaN                   N
# 17                                                NaN                   N
# 18                                                NaN                   N
# 19                                                NaN                   N
# 20                                                NaN                   N
# 21                                                NaN                   Y
# 22                                                NaN                   N
# 23                                                NaN                   N
# 24                                                NaN                   N
#
#      road_name  road_bunji1  road_bunji2           Close_date Close_result  \
# 0       해운대해변로         30.0          NaN  2018-06-14 00:00:00           배당
# 1       마린시티2로         33.0          NaN  2017-03-30 00:00:00           배당
# 2     모라로110번길         88.0          NaN  2017-12-13 00:00:00           배당
# 3   황령대로319번가길        110.0          NaN  2017-12-27 00:00:00           배당
# 4          오작로         51.0          NaN  2016-10-04 00:00:00           배당
# 5         일산봉로         58.0          NaN  2017-10-25 00:00:00           배당
# 6         동삼서로         61.0          NaN  2016-11-03 00:00:00           배당
# 7          분포로        111.0          NaN  2016-11-22 00:00:00           배당
# 8      천마로27번길         10.0          NaN  2016-09-27 00:00:00           배당
# 9      재반로84번길         96.0          7.0  2017-12-27 00:00:00           배당
# 10    동평로405번길         69.0          NaN  2018-02-28 00:00:00           배당
# 11         태종로        705.0          NaN  2017-02-13 00:00:00           배당
# 12         비봉로         37.0          NaN  2018-04-19 00:00:00           배당
# 13  좌동순환로433번길         30.0          NaN  2017-07-24 00:00:00           배당
# 14    과정로343번길         43.0          NaN  2016-12-20 00:00:00           배당
# 15       광안해변로        418.0          NaN  2018-01-31 00:00:00           배당
# 16         재반로        141.0          NaN  2018-05-16 00:00:00           배당
# 17        차밭골로         24.0          NaN  2016-12-22 00:00:00           배당
# 18    웃서발로31번길         22.0          NaN  2016-12-01 00:00:00           배당
# 19         수성로          2.0          1.0  2017-04-05 00:00:00           배당
# 20       금강공원로          2.0          NaN  2016-08-23 00:00:00           배당
# 21         봉래길         94.0          NaN  2016-12-20 00:00:00           배당
# 22         재반로        141.0          NaN  2016-09-26 00:00:00           배당
# 23        해돋이로        313.0          NaN  2017-06-07 00:00:00           배당
# 24    차밭골로20번길         21.0          NaN  2016-11-30 00:00:00           배당
#
#       point.y     point.x Hammer_price
# 0   35.162717  129.137048    760000000
# 1   35.156633  129.145068    971889999
# 2   35.184601  128.996765     93399999
# 3   35.154180  129.089081    256899000
# 4   35.099630  128.998874    158660000
# 5   35.086933  129.065706    206989000
# 6   35.084049  129.070231    135500000
# 7   35.127808  129.112206    640299999
# 8   35.080817  129.020155     77380000
# 9   35.187903  129.130913    177070000
# 10  35.176581  129.071228    240000001
# 11  35.071897  129.076585    221017200
# 12  35.098222  128.965136     31888000
# 13  35.161948  129.179110    518800000
# 14  35.188580  129.089335    670190000
# 15  35.159833  129.131154    531100000
# 16  35.191666  129.126864    143999000
# 17  35.216645  129.079149    133000000
# 18  35.081003  129.068091    126651100
# 19  35.132840  129.042040     73899900
# 20  35.218631  129.084142    206119000
# 21  35.090638  129.050729     60299000
# 22  35.191666  129.126864    136630000
# 23  35.104126  129.016082    362000000
# 24  35.217180  129.080055    122000000
#
# [25 rows x 41 columns]

# %%
df.describe()
# Out:
#        Auction_key   Claim_price  Auction_count  Auction_miscarriage_count  \
# count  1933.000000  1.933000e+03    1933.000000                1933.000000
# mean   1380.271081  3.703908e+08       1.836006                   0.788412
# std     801.670470  1.337869e+09       0.938319                   0.831715
# min       1.000000  0.000000e+00       1.000000                   0.000000
# 25%     691.000000  7.746112e+07       1.000000                   0.000000
# 50%    1395.000000  1.728143e+08       2.000000                   1.000000
# 75%    2062.000000  3.565089e+08       2.000000                   1.000000
# max    2762.000000  2.286481e+10      13.000000                   9.000000
#
#        Total_land_gross_area  Total_land_real_area  Total_land_auction_area  \
# count           1.933000e+03           1933.000000              1933.000000
# mean            3.458714e+04             42.333802                41.310776
# std             9.442101e+04             65.274404                65.385900
# min             0.000000e+00              0.000000                 0.000000
# 25%             2.997000e+03             25.870000                24.570000
# 50%             1.424140e+04             37.510000                36.790000
# 75%             4.140310e+04             51.790000                51.320000
# max             3.511936e+06           2665.840000              2665.840000
#
#        Total_building_area  Total_building_auction_area  \
# count          1933.000000                  1933.000000
# mean             96.417693                    94.148810
# std             106.323240                   106.845985
# min               9.390000                     1.500000
# 25%              61.520000                    59.970000
# 50%              84.900000                    84.860000
# 75%             114.940000                   114.850000
# max            4255.070000                  4255.070000
#
#        Total_appraisal_price  Minimum_sales_price  addr_bunji1  addr_bunji2  \
# count           1.933000e+03         1.933000e+03  1929.000000   889.000000
# mean            4.973592e+08         4.155955e+08   601.952307    22.742407
# std             7.873851e+08         5.030312e+08   554.119824    67.000807
# min             4.285000e+06         4.285000e+06     1.000000     1.000000
# 25%             2.090000e+08         1.750000e+08   189.000000     1.000000
# 50%             3.600000e+08         3.120000e+08   482.000000     5.000000
# 75%             5.720000e+08         4.864000e+08   834.000000    18.000000
# max             2.777500e+10         1.422080e+10  4937.000000  1414.000000
#
#        Total_floor  Current_floor  road_bunji1  road_bunji2      point.y  \
# count  1933.000000    1933.000000  1909.000000   155.000000  1933.000000
# mean     16.980859       8.817900   127.441069    12.748387    36.698018
# std       9.509021       8.044644   188.394217    10.735663     1.150269
# min       3.000000       0.000000     1.000000     1.000000    35.051385
# 25%      12.000000       3.000000    24.000000     5.000000    35.188590
# 50%      15.000000       7.000000    57.000000     9.000000    37.500862
# 75%      21.000000      12.000000   145.000000    17.500000    37.566116
# max      80.000000      65.000000  1716.000000    55.000000    37.685575
#
#            point.x  Hammer_price
# count  1933.000000  1.933000e+03
# mean    127.731667  4.726901e+08
# std       0.993055  5.574493e+08
# min     126.809393  6.303000e+06
# 25%     126.959167  1.975550e+08
# 50%     127.065003  3.544500e+08
# 75%     129.018054  5.599000e+08
# max     129.255872  1.515100e+10

# %%
print(df.dropna(axis=1).shape) #결측치가 있는 열 제거
# Out:
# (1933, 35)

# %%
df.isnull().sum(axis=0) #확인
# Out:
# Auction_key                       0
# Auction_class                     0
# Bid_class                         0
# Claim_price                       0
# Appraisal_company                 0
# Appraisal_date                    0
# Auction_count                     0
# Auction_miscarriage_count         0
# Total_land_gross_area             0
# Total_land_real_area              0
# Total_land_auction_area           0
# Total_building_area               0
# Total_building_auction_area       0
# Total_appraisal_price             0
# Minimum_sales_price               0
# First_auction_date                0
# Final_auction_date                0
# Final_result                      0
# Creditor                          0
# addr_do                           0
# addr_si                           0
# addr_dong                         0
# addr_li                        1910
# addr_san                          0
# addr_bunji1                       4
# addr_bunji2                    1044
# addr_etc                          0
# Apartment_usage                   0
# Preserve_regist_date              0
# Total_floor                       0
# Current_floor                     0
# Specific                       1869
# Share_auction_YorN                0
# road_name                         0
# road_bunji1                      24
# road_bunji2                    1778
# Close_date                        0
# Close_result                      0
# point.y                           0
# point.x                           0
# Hammer_price                      0
# dtype: int64

# %%
df.corr #변수들 간의 상관관계를 알아보기 위함
# Out:
# <bound method DataFrame.corr of       Auction_key Auction_class Bid_class  Claim_price Appraisal_company  \
# 0            2687            임의        개별   1766037301              정명감정
# 1            2577            임의        일반    152946867               희감정
# 2            2197            임의        개별     11326510              혜림감정
# 3            2642            임의        일반    183581724              신라감정
# 4            1958            강제        일반     45887671              나라감정
# ...           ...           ...       ...          ...               ...
# 1928         1567            강제        일반    280000000              삼창감정
# 1929         1295            임의        일반    200000000              삼상감정
# 1930          254            임의        일반    354805459              서초감정
# 1931         1486            강제        일반     80000000              한미감정
# 1932          937            임의        일반    180000000              자연감정
#
#            Appraisal_date  Auction_count  Auction_miscarriage_count  \
# 0     2017-07-26 00:00:00              2                          1
# 1     2016-09-12 00:00:00              2                          1
# 2     2016-11-22 00:00:00              3                          2
# 3     2016-12-13 00:00:00              2                          1
# 4     2016-03-07 00:00:00              2                          1
# ...                   ...            ...                        ...
# 1928  2017-02-16 00:00:00              1                          0
# 1929  2015-02-21 00:00:00              2                          1
# 1930  2016-10-21 00:00:00              2                          1
# 1931  2016-06-17 00:00:00              2                          1
# 1932  2015-04-17 00:00:00              2                          1
#
#       Total_land_gross_area  Total_land_real_area  ...  Specific  \
# 0                   12592.0                 37.35  ...       NaN
# 1                   42478.1                 18.76  ...       NaN
# 2                  149683.1                 71.00  ...       NaN
# 3                   24405.0                 32.98  ...       NaN
# 4                     774.0                 45.18  ...       NaN
# ...                     ...                   ...  ...       ...
# 1928                66419.3                 40.55  ...       NaN
# 1929                20433.8                 39.60  ...       NaN
# 1930                 7460.8                 19.03  ...       NaN
# 1931                16875.8                 42.20  ...       NaN
# 1932                32457.1                 45.68  ...       NaN
#
#       Share_auction_YorN   road_name  road_bunji1  road_bunji2  \
# 0                      N      해운대해변로         30.0          NaN
# 1                      N      마린시티2로         33.0          NaN
# 2                      N    모라로110번길         88.0          NaN
# 3                      N  황령대로319번가길        110.0          NaN
# 4                      N         오작로         51.0          NaN
# ...                  ...         ...          ...          ...
# 1928                   N      노해로66길         21.0          NaN
# 1929                   N      덕릉로94길         21.0          NaN
# 1930                   N         소공로         35.0          NaN
# 1931                   N        우이천로        328.0          NaN
# 1932                   N      양천로55길         55.0          NaN
#
#                Close_date Close_result    point.y     point.x Hammer_price
# 0     2018-06-14 00:00:00           배당  35.162717  129.137048    760000000
# 1     2017-03-30 00:00:00           배당  35.156633  129.145068    971889999
# 2     2017-12-13 00:00:00           배당  35.184601  128.996765     93399999
# 3     2017-12-27 00:00:00           배당  35.154180  129.089081    256899000
# 4     2016-10-04 00:00:00           배당  35.099630  128.998874    158660000
# ...                   ...          ...        ...         ...          ...
# 1928  2017-08-30 00:00:00           배당  37.648810  127.048683    402500000
# 1929  2017-05-24 00:00:00           배당  37.663291  127.077063    430234600
# 1930  2018-03-29 00:00:00           배당  37.558319  126.981994   1118999990
# 1931  2017-01-24 00:00:00           배당  37.647061  127.028002    403000000
# 1932  2016-08-25 00:00:00           배당  37.566255  126.848961    686010000
#
# [1933 rows x 41 columns]>

# %%
sns.pairplot(df)
# Out:
# C:\Users\lcm01\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\lcm01\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# : 각 변수 사이의 상관관계 확인 가능

# %% [markdown]
# ## 실행 확인하기!!
#
# #VIF 확인
# from statsmodels.stats.outliers_influence import variance_inflation_factor
#
# vif = pd.DataFrame()
# vif["VIF Factor"] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
# vif["features"] = df.columns
# vif.sort_values(["VIF Factor"], ascending=[False])

# %% [markdown]
# # 1-1. 범주형 변수 인코딩1
# - 서울: 0 , 부산: 1 로 인코딩하자

# %%
#한글 깨짐 현상 해결
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
df.addr_do.value_counts()
# Out:
# 서울    1242
# 부산     691
# Name: addr_do, dtype: int64

# %%
sns.countplot(df.addr_do)

# %%
def encoding_1 (x):
    if x == "서울":
        return 0
    else:
        return 1
df['d_addr_do'] = df['addr_do'].apply(encoding_1)
#서울/부산 더미변수열 생성  : 부산이면 0, 부산이 아니면(=서울이면) 1

# %%
df.tail() #f확인
# Out:
#       Auction_key Auction_class Bid_class  Claim_price Appraisal_company  \
# 1928         1567            강제        일반    280000000              삼창감정
# 1929         1295            임의        일반    200000000              삼상감정
# 1930          254            임의        일반    354805459              서초감정
# 1931         1486            강제        일반     80000000              한미감정
# 1932          937            임의        일반    180000000              자연감정
#
#            Appraisal_date  Auction_count  Auction_miscarriage_count  \
# 1928  2017-02-16 00:00:00              1                          0
# 1929  2015-02-21 00:00:00              2                          1
# 1930  2016-10-21 00:00:00              2                          1
# 1931  2016-06-17 00:00:00              2                          1
# 1932  2015-04-17 00:00:00              2                          1
#
#       Total_land_gross_area  Total_land_real_area  ...  Share_auction_YorN  \
# 1928                66419.3                 40.55  ...                   N
# 1929                20433.8                 39.60  ...                   N
# 1930                 7460.8                 19.03  ...                   N
# 1931                16875.8                 42.20  ...                   N
# 1932                32457.1                 45.68  ...                   N
#
#       road_name  road_bunji1  road_bunji2           Close_date Close_result  \
# 1928     노해로66길         21.0          NaN  2017-08-30 00:00:00           배당
# 1929     덕릉로94길         21.0          NaN  2017-05-24 00:00:00           배당
# 1930        소공로         35.0          NaN  2018-03-29 00:00:00           배당
# 1931       우이천로        328.0          NaN  2017-01-24 00:00:00           배당
# 1932     양천로55길         55.0          NaN  2016-08-25 00:00:00           배당
#
#         point.y     point.x Hammer_price d_addr_do
# 1928  37.648810  127.048683    402500000         0
# 1929  37.663291  127.077063    430234600         0
# 1930  37.558319  126.981994   1118999990         0
# 1931  37.647061  127.028002    403000000         0
# 1932  37.566255  126.848961    686010000         0
#
# [5 rows x 42 columns]

# %%
df.d_addr_do.value_counts()
# Out:
# 0    1242
# 1     691
# Name: d_addr_do, dtype: int64

# %% [markdown]
# # 1-2. 범주형 변수 인코딩2
# - 일반: 10 , 개별: 01, 일괄: 00 로 인코딩하자

# %%
df.Bid_class.value_counts()
# Out:
# 일반    1796
# 개별     125
# 일괄      12
# Name: Bid_class, dtype: int64

# %%
sns.countplot(df.Bid_class)

# %%
# 일반인 경우 1을 return
def encoding_2 (x):
    if x == "일반":
        return 1

    else: 
        return 0

df['Bid_i'] = df['Bid_class'].apply(encoding_2)

# %%
# 개별인 경우 1을 return
def encoding_3 (x):
    if x == "개별":
        return 1

    else: 
        return 0

df['Bid_g'] = df['Bid_class'].apply(encoding_3)

# %%
df.head()
# Out:
#    Auction_key Auction_class Bid_class  Claim_price Appraisal_company  \
# 0         2687            임의        개별   1766037301              정명감정
# 1         2577            임의        일반    152946867               희감정
# 2         2197            임의        개별     11326510              혜림감정
# 3         2642            임의        일반    183581724              신라감정
# 4         1958            강제        일반     45887671              나라감정
#
#         Appraisal_date  Auction_count  Auction_miscarriage_count  \
# 0  2017-07-26 00:00:00              2                          1
# 1  2016-09-12 00:00:00              2                          1
# 2  2016-11-22 00:00:00              3                          2
# 3  2016-12-13 00:00:00              2                          1
# 4  2016-03-07 00:00:00              2                          1
#
#    Total_land_gross_area  Total_land_real_area  ...  road_bunji1  road_bunji2  \
# 0                12592.0                 37.35  ...         30.0          NaN
# 1                42478.1                 18.76  ...         33.0          NaN
# 2               149683.1                 71.00  ...         88.0          NaN
# 3                24405.0                 32.98  ...        110.0          NaN
# 4                  774.0                 45.18  ...         51.0          NaN
#
#             Close_date  Close_result    point.y     point.x Hammer_price  \
# 0  2018-06-14 00:00:00            배당  35.162717  129.137048    760000000
# 1  2017-03-30 00:00:00            배당  35.156633  129.145068    971889999
# 2  2017-12-13 00:00:00            배당  35.184601  128.996765     93399999
# 3  2017-12-27 00:00:00            배당  35.154180  129.089081    256899000
# 4  2016-10-04 00:00:00            배당  35.099630  128.998874    158660000
#
#   d_addr_do Bid_i Bid_g
# 0         1     0     1
# 1         1     1     0
# 2         1     0     1
# 3         1     1     0
# 4         1     1     0
#
# [5 rows x 44 columns]

# %% [markdown]
# # 1-3. 범주형 변수 인코딩3
# - 저층: 10 , 중층: 01, 고층: 00 로 인코딩하자

# %%
df['Current_floor'].plot.hist(color='grey', edgecolor='black')

# %%
# 저/중/고층 피처 생성
def floor(x):
    if 0 <= x <= 9:
        return '저층'
    elif 10 <= x <= 20:
        return '중층'
    else:
        return '고층'

df['층수'] = df['Current_floor'].apply(floor)

# %%
df.head()
# Out:
#    Auction_key Auction_class Bid_class  Claim_price Appraisal_company  \
# 0         2687            임의        개별   1766037301              정명감정
# 1         2577            임의        일반    152946867               희감정
# 2         2197            임의        개별     11326510              혜림감정
# 3         2642            임의        일반    183581724              신라감정
# 4         1958            강제        일반     45887671              나라감정
#
#         Appraisal_date  Auction_count  Auction_miscarriage_count  \
# 0  2017-07-26 00:00:00              2                          1
# 1  2016-09-12 00:00:00              2                          1
# 2  2016-11-22 00:00:00              3                          2
# 3  2016-12-13 00:00:00              2                          1
# 4  2016-03-07 00:00:00              2                          1
#
#    Total_land_gross_area  Total_land_real_area  ...  road_bunji2  \
# 0                12592.0                 37.35  ...          NaN
# 1                42478.1                 18.76  ...          NaN
# 2               149683.1                 71.00  ...          NaN
# 3                24405.0                 32.98  ...          NaN
# 4                  774.0                 45.18  ...          NaN
#
#             Close_date  Close_result    point.y     point.x Hammer_price  \
# 0  2018-06-14 00:00:00            배당  35.162717  129.137048    760000000
# 1  2017-03-30 00:00:00            배당  35.156633  129.145068    971889999
# 2  2017-12-13 00:00:00            배당  35.184601  128.996765     93399999
# 3  2017-12-27 00:00:00            배당  35.154180  129.089081    256899000
# 4  2016-10-04 00:00:00            배당  35.099630  128.998874    158660000
#
#   d_addr_do Bid_i Bid_g  층수
# 0         1     0     1  저층
# 1         1     1     0  고층
# 2         1     0     1  중층
# 3         1     1     0  중층
# 4         1     1     0  저층
#
# [5 rows x 45 columns]

# %%
# 저층인 경우 1을 return
def encoding_f1 (x):
    if x == "저층":
        return 1

    else: 
        return 0

df['floor_low'] = df['층수'].apply(encoding_f1)

# %%
# 중층인 경우 1을 return
def encoding_f2 (x):
    if x == "중층":
        return 1

    else: 
        return 0

df['floor_mid'] = df['층수'].apply(encoding_f2)

# %%
df.head()
# Out:
#    Auction_key Auction_class Bid_class  Claim_price Appraisal_company  \
# 0         2687            임의        개별   1766037301              정명감정
# 1         2577            임의        일반    152946867               희감정
# 2         2197            임의        개별     11326510              혜림감정
# 3         2642            임의        일반    183581724              신라감정
# 4         1958            강제        일반     45887671              나라감정
#
#         Appraisal_date  Auction_count  Auction_miscarriage_count  \
# 0  2017-07-26 00:00:00              2                          1
# 1  2016-09-12 00:00:00              2                          1
# 2  2016-11-22 00:00:00              3                          2
# 3  2016-12-13 00:00:00              2                          1
# 4  2016-03-07 00:00:00              2                          1
#
#    Total_land_gross_area  Total_land_real_area  ...  Close_result    point.y  \
# 0                12592.0                 37.35  ...            배당  35.162717
# 1                42478.1                 18.76  ...            배당  35.156633
# 2               149683.1                 71.00  ...            배당  35.184601
# 3                24405.0                 32.98  ...            배당  35.154180
# 4                  774.0                 45.18  ...            배당  35.099630
#
#       point.x  Hammer_price  d_addr_do Bid_i Bid_g  층수 floor_low floor_mid
# 0  129.137048     760000000          1     0     1  저층         1         0
# 1  129.145068     971889999          1     1     0  고층         0         0
# 2  128.996765      93399999          1     0     1  중층         0         1
# 3  129.089081     256899000          1     1     0  중층         0         1
# 4  128.998874     158660000          1     1     0  저층         1         0
#
# [5 rows x 47 columns]

# %% [markdown]
# # 2. 선형회귀분석

# %% [markdown]
# y: Hammer_price
#
# x: 나머지 변수

# %%
# 선형회귀분석을 위한 x1 설정
# Hammer_price와 관련없는 변수 제거 후 x1 설정했습니다!
x1 = df[['Claim_price', 'Auction_count', 
        'Auction_miscarriage_count', 'Total_land_gross_area', 
        'Total_land_real_area', 'Total_land_auction_area', 
        'Total_building_area', 'Total_building_area',
        'Total_appraisal_price', 'Minimum_sales_price',
        'Total_floor', 'Current_floor',
                  
        'd_addr_do', 'Bid_i', 'Bid_g', 'floor_low', 'floor_mid']]

# %%
y1 = df['Hammer_price']

# %%
x1
# Out:
#       Claim_price  Auction_count  Auction_miscarriage_count  \
# 0      1766037301              2                          1
# 1       152946867              2                          1
# 2        11326510              3                          2
# 3       183581724              2                          1
# 4        45887671              2                          1
# ...           ...            ...                        ...
# 1928    280000000              1                          0
# 1929    200000000              2                          1
# 1930    354805459              2                          1
# 1931     80000000              2                          1
# 1932    180000000              2                          1
#
#       Total_land_gross_area  Total_land_real_area  Total_land_auction_area  \
# 0                   12592.0                 37.35                    37.35
# 1                   42478.1                 18.76                    18.76
# 2                  149683.1                 71.00                    71.00
# 3                   24405.0                 32.98                    32.98
# 4                     774.0                 45.18                    45.18
# ...                     ...                   ...                      ...
# 1928                66419.3                 40.55                    40.55
# 1929                20433.8                 39.60                    39.60
# 1930                 7460.8                 19.03                    19.03
# 1931                16875.8                 42.20                    42.20
# 1932                32457.1                 45.68                    45.68
#
#       Total_building_area  Total_building_area  Total_appraisal_price  \
# 0                  181.77               181.77              836000000
# 1                  118.38               118.38             1073000000
# 2                   49.94                49.94              119000000
# 3                   84.91                84.91              288400000
# 4                   84.96                84.96              170000000
# ...                   ...                  ...                    ...
# 1928                84.87                84.87              401000000
# 1929               114.81               114.81              454000000
# 1930               133.98               133.98             1285000000
# 1931                84.94                84.94              407000000
# 1932               102.92               102.92              750000000
#
#       Minimum_sales_price  Total_floor  Current_floor  d_addr_do  Bid_i  \
# 0               668800000           45              5          1      0
# 1               858400000           70             51          1      1
# 2                76160000           15             14          1      0
# 3               230720000           20             11          1      1
# 4               136000000            7              7          1      1
# ...                   ...          ...            ...        ...    ...
# 1928            401000000           21             15          0      1
# 1929            363200000           23             23          0      1
# 1930           1028000000           32             19          0      1
# 1931            325600000           15             11          0      1
# 1932            600000000           22              7          0      1
#
#       Bid_g  floor_low  floor_mid
# 0         1          1          0
# 1         0          0          0
# 2         1          0          1
# 3         0          0          1
# 4         0          1          0
# ...     ...        ...        ...
# 1928      0          0          1
# 1929      0          0          0
# 1930      0          0          1
# 1931      0          0          1
# 1932      0          1          0
#
# [1933 rows x 17 columns]

# %%
y1
# Out:
# 0        760000000
# 1        971889999
# 2         93399999
# 3        256899000
# 4        158660000
#            ...
# 1928     402500000
# 1929     430234600
# 1930    1118999990
# 1931     403000000
# 1932     686010000
# Name: Hammer_price, Length: 1933, dtype: int64

# %%
x1.shape, y1.shape
# Out:
# ((1933, 17), (1933,))

# %%
#다중공선성을 알아보자
x1.corr()
# Out:
#                            Claim_price  Auction_count  \
# Claim_price                   1.000000       0.013312
# Auction_count                 0.013312       1.000000
# Auction_miscarriage_count     0.015411       0.972918
# Total_land_gross_area         0.003771      -0.045697
# Total_land_real_area          0.180421       0.062824
# Total_land_auction_area       0.182207       0.062868
# Total_building_area           0.202379       0.107074
# Total_building_area           0.202379       0.107074
# Total_appraisal_price         0.248846       0.071038
# Minimum_sales_price           0.261076      -0.036716
# Total_floor                   0.016466      -0.052329
# Current_floor                 0.043258      -0.029124
# d_addr_do                    -0.100203       0.053300
# Bid_i                        -0.273204      -0.179376
# Bid_g                         0.265928       0.173782
# floor_low                    -0.014631       0.024948
# floor_mid                     0.004776      -0.007696
#
#                            Auction_miscarriage_count  Total_land_gross_area  \
# Claim_price                                 0.015411               0.003771
# Auction_count                               0.972918              -0.045697
# Auction_miscarriage_count                   1.000000              -0.050457
# Total_land_gross_area                      -0.050457               1.000000
# Total_land_real_area                        0.069582               0.049791
# Total_land_auction_area                     0.069392               0.048225
# Total_building_area                         0.118290               0.017401
# Total_building_area                         0.118290               0.017401
# Total_appraisal_price                       0.077547               0.041896
# Minimum_sales_price                        -0.033039               0.067135
# Total_floor                                -0.045343               0.100557
# Current_floor                              -0.021852               0.094385
# d_addr_do                                   0.056091              -0.016506
# Bid_i                                      -0.189082               0.053319
# Bid_g                                       0.183279              -0.057026
# floor_low                                   0.012713              -0.092402
# floor_mid                                   0.003126               0.061691
#
#                            Total_land_real_area  Total_land_auction_area  \
# Claim_price                            0.180421                 0.182207
# Auction_count                          0.062824                 0.062868
# Auction_miscarriage_count              0.069582                 0.069392
# Total_land_gross_area                  0.049791                 0.048225
# Total_land_real_area                   1.000000                 0.996224
# Total_land_auction_area                0.996224                 1.000000
# Total_building_area                    0.940361                 0.938144
# Total_building_area                    0.940361                 0.938144
# Total_appraisal_price                  0.842248                 0.845243
# Minimum_sales_price                    0.711515                 0.715891
# Total_floor                           -0.072543                -0.068385
# Current_floor                         -0.062673                -0.061274
# d_addr_do                             -0.064039                -0.059051
# Bid_i                                 -0.055658                -0.059150
# Bid_g                                 -0.056343                -0.052899
# floor_low                              0.049879                 0.050809
# floor_mid                             -0.035499                -0.038470
#
#                            Total_building_area  Total_building_area  \
# Claim_price                           0.202379             0.202379
# Auction_count                         0.107074             0.107074
# Auction_miscarriage_count             0.118290             0.118290
# Total_land_gross_area                 0.017401             0.017401
# Total_land_real_area                  0.940361             0.940361
# Total_land_auction_area               0.938144             0.938144
# Total_building_area                   1.000000             1.000000
# Total_building_area                   1.000000             1.000000
# Total_appraisal_price                 0.900302             0.900302
# Minimum_sales_price                   0.783299             0.783299
# Total_floor                           0.107069             0.107069
# Current_floor                         0.071110             0.071110
# d_addr_do                            -0.067411            -0.067411
# Bid_i                                -0.066550            -0.066550
# Bid_g                                -0.043855            -0.043855
# floor_low                            -0.025719            -0.025719
# floor_mid                            -0.016202            -0.016202
#
#                            Total_appraisal_price  Minimum_sales_price  \
# Claim_price                             0.248846             0.261076
# Auction_count                           0.071038            -0.036716
# Auction_miscarriage_count               0.077547            -0.033039
# Total_land_gross_area                   0.041896             0.067135
# Total_land_real_area                    0.842248             0.711515
# Total_land_auction_area                 0.845243             0.715891
# Total_building_area                     0.900302             0.783299
# Total_building_area                     0.900302             0.783299
# Total_appraisal_price                   1.000000             0.960357
# Minimum_sales_price                     0.960357             1.000000
# Total_floor                             0.169577             0.223407
# Current_floor                           0.151757             0.201913
# d_addr_do                              -0.229401            -0.295578
# Bid_i                                  -0.080290            -0.051115
# Bid_g                                  -0.031358            -0.049070
# floor_low                              -0.044374            -0.065873
# floor_mid                              -0.028173            -0.029150
#
#                            Total_floor  Current_floor  d_addr_do     Bid_i  \
# Claim_price                   0.016466       0.043258  -0.100203 -0.273204
# Auction_count                -0.052329      -0.029124   0.053300 -0.179376
# Auction_miscarriage_count    -0.045343      -0.021852   0.056091 -0.189082
# Total_land_gross_area         0.100557       0.094385  -0.016506  0.053319
# Total_land_real_area         -0.072543      -0.062673  -0.064039 -0.055658
# Total_land_auction_area      -0.068385      -0.061274  -0.059051 -0.059150
# Total_building_area           0.107069       0.071110  -0.067411 -0.066550
# Total_building_area           0.107069       0.071110  -0.067411 -0.066550
# Total_appraisal_price         0.169577       0.151757  -0.229401 -0.080290
# Minimum_sales_price           0.223407       0.201913  -0.295578 -0.051115
# Total_floor                   1.000000       0.708154   0.165918  0.113745
# Current_floor                 0.708154       1.000000   0.126812  0.016306
# d_addr_do                     0.165918       0.126812   1.000000  0.008304
# Bid_i                         0.113745       0.016306   0.008304  1.000000
# Bid_g                        -0.112539      -0.018632  -0.003004 -0.952026
# floor_low                    -0.451263      -0.740449  -0.126096 -0.041956
# floor_mid                     0.162960       0.381047   0.071833  0.033877
#
#                               Bid_g  floor_low  floor_mid
# Claim_price                0.265928  -0.014631   0.004776
# Auction_count              0.173782   0.024948  -0.007696
# Auction_miscarriage_count  0.183279   0.012713   0.003126
# Total_land_gross_area     -0.057026  -0.092402   0.061691
# Total_land_real_area      -0.056343   0.049879  -0.035499
# Total_land_auction_area   -0.052899   0.050809  -0.038470
# Total_building_area       -0.043855  -0.025719  -0.016202
# Total_building_area       -0.043855  -0.025719  -0.016202
# Total_appraisal_price     -0.031358  -0.044374  -0.028173
# Minimum_sales_price       -0.049070  -0.065873  -0.029150
# Total_floor               -0.112539  -0.451263   0.162960
# Current_floor             -0.018632  -0.740449   0.381047
# d_addr_do                 -0.003004  -0.126096   0.071833
# Bid_i                     -0.952026  -0.041956   0.033877
# Bid_g                      1.000000   0.038117  -0.028526
# floor_low                  0.038117   1.000000  -0.855134
# floor_mid                 -0.028526  -0.855134   1.000000

# %% [markdown]
# ~area 변수들끼리 상관관계가 높음을 확인할 수 있다.

# %%
#VIF를 확인하자!
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(x1.values, i) for i in range(x1.shape[1])]
vif["features"] = x1.columns
vif.sort_values(["VIF Factor"], ascending=[False])
# Out:
# C:\Users\lcm01\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:185: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#     VIF Factor                   features
# 6          inf        Total_building_area
# 7          inf        Total_building_area
# 4   208.090736       Total_land_real_area
# 5   193.554329    Total_land_auction_area
# 8    90.973177      Total_appraisal_price
# 1    85.257553              Auction_count
# 13   65.479757                      Bid_i
# 9    56.156014        Minimum_sales_price
# 2    34.719053  Auction_miscarriage_count
# 15   30.614405                  floor_low
# 11   11.376226              Current_floor
# 10   10.981380                Total_floor
# 16    8.428816                  floor_mid
# 14    5.604167                      Bid_g
# 12    2.099767                  d_addr_do
# 0     1.265361                Claim_price
# 3     1.205500      Total_land_gross_area

# %% [markdown]
# 다중공선성이 큰 변수들을 제거하고 다시 데이터를 만들자!
# :: 코드를 다시 돌려보고 체크하면서 'Total_building_area' 열을 두 번 넣은 걸 발견했습니다ㅠㅠ VIF로 체크해서 뺀 변수로 간주할게요 죄송합니당

# %%
#다중공선성이 큰 변수들이 많지만 회귀분석을 위해 상위 4개만 제거

# %%
x2 = df[['Claim_price', 'Auction_count', 
        'Auction_miscarriage_count', 
         'Total_land_gross_area', 
        'Total_building_area',
        'Total_appraisal_price', 
         'Minimum_sales_price',
        'Total_floor', 
         'Current_floor',
                  
        'd_addr_do', 'Bid_i', 'Bid_g', 'floor_low', 'floor_mid']]

# %%
# train, test data 분할
from sklearn.model_selection import train_test_split

x2_train, x2_test, y2_train, y2_test = train_test_split(x2, y1, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

#모델 불러옴
model = LinearRegression()
#train data에 fit시킴
model.fit(x2_train, y1_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#모델의 R-square
model.score(x2_train, y1_train)
# Out:
# 0.9910752782107796

# %%
#MSE를 계산하자
import sklearn as sk
sk.metrics.mean_squared_error(y1_train, model.predict(x2_train))

#MSE의 값이 매우 큼을 알 수 있음...
# Out:
# 3169731350268053.0

# %%
print(model.coef_) #추정된 회귀계수와
print(model.intercept_) #intercept를 출력하자!
# Out:
# [ 4.41179231e-03 -1.73437140e+07  3.72960230e+07  2.24587054e+01
#  -3.18434532e+05  4.29484622e-02  1.08304488e+00  2.89081600e+05
#  -7.63635984e+05 -1.20784289e+07 -3.91724282e+07 -6.32196199e+07
#  -7.40050019e+06 -2.24982924e+06]
# 85127353.16815108

# %%
#test데이터 예측
model.predict(x2_test)
# Out:
# array([4.27405726e+08, 9.35120941e+08, 1.96433970e+08, 2.88558691e+08,
#        7.13644768e+08, 8.08504491e+07, 6.12497024e+08, 3.26613339e+08,
#        9.55162907e+08, 4.15486764e+08, 5.90999971e+08, 1.97525226e+08,
#        7.35138930e+08, 3.72674278e+08, 1.01244446e+08, 2.66678444e+08,
#        9.08164534e+07, 1.41304972e+08, 8.42501180e+08, 1.29298227e+09,
#        4.43653653e+08, 2.34525494e+08, 1.65451287e+09, 2.77188238e+08,
#        1.34393025e+08, 1.51583765e+08, 5.91667480e+08, 1.03199620e+09,
#        4.10302654e+08, 4.49576716e+07, 1.13274908e+09, 3.19546549e+08,
#        3.35162634e+08, 6.59998547e+08, 5.97385733e+08, 3.34941621e+08,
#        4.88302366e+08, 2.99222546e+08, 5.80981336e+08, 5.04902095e+08,
#        9.60212681e+08, 6.91696390e+07, 3.10327571e+08, 1.90519001e+07,
#        3.85298470e+08, 1.00652981e+09, 1.79091765e+08, 1.34076142e+09,
#        4.40871891e+08, 3.33713146e+08, 8.22203789e+08, 9.37772173e+08,
#        1.49288660e+08, 3.24718020e+08, 8.68017499e+08, 1.81827114e+08,
#        1.57014310e+08, 2.09774318e+08, 9.48618011e+07, 1.61423745e+08,
#        1.78242798e+08, 1.28497880e+08, 1.37637834e+08, 4.47673645e+08,
#        3.96687164e+08, 1.13482295e+08, 2.55117505e+08, 3.97460195e+08,
#        6.16019152e+08, 1.86468757e+08, 1.16135734e+08, 7.15270354e+07,
#        1.09938521e+08, 4.09854370e+08, 1.53047187e+08, 4.10730114e+08,
#        6.91412111e+08, 1.91504587e+08, 1.49941844e+08, 3.87553126e+08,
#        1.49473139e+08, 2.61498925e+08, 4.35547370e+08, 1.93462689e+08,
#        3.11041265e+08, 1.59830534e+08, 4.81739997e+08, 7.19797494e+08,
#        3.37526597e+08, 5.43317195e+08, 1.50421711e+08, 3.55196603e+08,
#        4.17174923e+08, 1.23497679e+09, 8.49118435e+07, 1.82425641e+08,
#        3.53048981e+08, 4.45137943e+08, 5.37247329e+08, 3.09290639e+08,
#        9.12345481e+07, 2.31080351e+08, 4.58874298e+08, 1.45482836e+08,
#        2.66414824e+08, 2.78917070e+08, 2.27044964e+08, 4.42066113e+08,
#        4.60468105e+07, 9.14644635e+07, 5.03981575e+08, 6.24887437e+08,
#        1.16129794e+09, 2.30749726e+08, 4.40278513e+08, 1.36464026e+08,
#        3.40606360e+08, 5.27041298e+08, 1.02306940e+09, 6.37449446e+08,
#        3.96696560e+08, 5.15401412e+08, 9.18945700e+08, 2.08660327e+08,
#        4.99698478e+08, 7.46622194e+08, 3.92999048e+08, 1.05584410e+09,
#        2.94509566e+08, 8.73534713e+08, 3.33710419e+08, 5.31089731e+08,
#        4.59051866e+08, 6.58967778e+08, 4.66679797e+08, 7.78524774e+07,
#        4.25974483e+07, 2.47615380e+08, 3.65013804e+08, 6.46191743e+08,
#        2.09634069e+08, 3.78052754e+08, 1.56444434e+08, 1.44975345e+08,
#        7.58113276e+08, 1.47763913e+08, 6.34137080e+08, 3.17246325e+08,
#        3.41782915e+08, 3.71112081e+08, 5.06452671e+08, 6.75829528e+08,
#        5.35884497e+08, 2.27636471e+08, 1.19839898e+09, 1.61701704e+08,
#        1.58382365e+09, 3.39354051e+08, 1.83706195e+08, 3.83192444e+08,
#        1.75843755e+08, 5.54916792e+08, 8.03561013e+08, 3.97250957e+08,
#        5.13107277e+08, 4.66570216e+07, 2.20903237e+08, 3.46292108e+08,
#        3.01830910e+08, 1.06053270e+09, 2.02595517e+08, 9.12233731e+07,
#        2.71209801e+08, 6.41260111e+08, 5.39476944e+08, 7.15382026e+08,
#        2.97057904e+08, 3.11138132e+08, 2.69909880e+08, 1.70586838e+09,
#        3.98886021e+08, 2.10475797e+08, 4.60838377e+08, 3.36296175e+08,
#        8.86984566e+08, 5.65518601e+08, 1.70839158e+08, 1.54377751e+08,
#        2.72973972e+08, 5.81044302e+07, 6.77037092e+08, 9.44836932e+07,
#        1.01616577e+09, 7.87917385e+08, 2.20816044e+08, 3.23458061e+08,
#        1.44314013e+09, 3.22931466e+09, 6.06107409e+08, 1.21021662e+08,
#        5.24924162e+08, 2.56463602e+08, 3.23384722e+08, 4.87285422e+08,
#        2.20118182e+08, 1.39777700e+08, 7.05922684e+08, 1.13882207e+09,
#        4.93814655e+08, 1.57029360e+09, 1.48714446e+08, 2.44582985e+08,
#        3.63492331e+08, 7.47663234e+08, 1.21443628e+09, 2.99510316e+08,
#        4.02589437e+08, 7.90399755e+08, 3.44403190e+08, 4.35692689e+08,
#        1.45442373e+09, 1.05139765e+09, 2.85138611e+08, 1.84611909e+08,
#        4.80736758e+08, 1.48140702e+08, 2.86757285e+08, 2.62845742e+08,
#        2.59852697e+08, 1.19776390e+08, 3.24562145e+08, 9.17353257e+08,
#        1.44759320e+09, 1.22248649e+08, 6.07526274e+07, 4.84785260e+08,
#        1.39246254e+09, 1.40621169e+09, 3.72680862e+08, 2.31615843e+08,
#        4.37166824e+08, 9.16748569e+08, 5.31722598e+08, 3.66485051e+08,
#        3.78420422e+08, 2.37535368e+08, 9.42883718e+08, 2.65418867e+08,
#        4.81835689e+08, 1.25611467e+08, 2.56301457e+08, 3.83830664e+08,
#        4.60632971e+08, 3.49070017e+08, 2.07575609e+08, 9.50780951e+07,
#        3.39477567e+08, 8.09561576e+08, 1.46972336e+08, 5.27333948e+08,
#        1.56776804e+08, 5.96053791e+08, 6.92965424e+08, 6.62425587e+08,
#        3.70634274e+08, 1.23220671e+09, 4.07147488e+08, 2.65044430e+08,
#        2.25732159e+08, 2.58445804e+08, 5.88186687e+08, 4.15900928e+08,
#        3.67870061e+08, 1.01061580e+08, 4.02349804e+08, 4.26027577e+08,
#        2.41458174e+08, 4.94467151e+08, 3.14065244e+08, 4.48766515e+08,
#        1.18995862e+08, 6.05051539e+08, 5.24794519e+08, 1.49228727e+09,
#        2.02682529e+08, 1.83855525e+08, 1.12742666e+09, 7.67315735e+08,
#        3.93517648e+08, 4.78377426e+08, 9.34881819e+07, 1.00423171e+08,
#        4.57878205e+08, 2.52227958e+08, 1.60889581e+08, 3.08018511e+08,
#        1.09774871e+08, 3.82548482e+08, 2.75499604e+08, 1.34070252e+08,
#        4.47851503e+08, 6.55486861e+08, 1.29779346e+08, 5.51481193e+08,
#        5.53998831e+08, 6.43808985e+08, 8.89601580e+07, 3.77121027e+08,
#        2.14052691e+08, 2.09271076e+08, 5.54248419e+08, 2.56159195e+08,
#        7.27168474e+08, 4.67850119e+08, 8.00467318e+08, 9.57477288e+08,
#        2.93541662e+08, 1.78985493e+08, 1.39043013e+09, 6.15314776e+08,
#        1.80972187e+09, 1.44146283e+08, 1.23392999e+08, 2.75905348e+08,
#        3.09623058e+08, 4.16163896e+08, 1.32877182e+08, 5.61123213e+08,
#        1.11582368e+08, 4.27405726e+08, 1.79918206e+08, 1.18800870e+08,
#        1.99187600e+08, 2.04354737e+08, 1.60779297e+08, 2.85916030e+08,
#        4.35720687e+08, 9.72839449e+08, 4.48096544e+08, 4.67539881e+08,
#        1.45616351e+08, 3.75568550e+08, 2.18103484e+08, 5.80368111e+08,
#        1.44290973e+08, 4.27975902e+08, 1.93886457e+08, 1.54533857e+08,
#        4.57035741e+08, 8.34292217e+08, 1.41316818e+08, 7.15767294e+08,
#        4.07476614e+08, 1.20607180e+09, 2.46141329e+08, 6.11842662e+08,
#        1.49576196e+08, 4.63685343e+08, 2.69139320e+08, 5.46892163e+07,
#        4.16480637e+08, 1.48020528e+08, 1.04491871e+09, 3.23933758e+08,
#        2.89985627e+08, 4.48202341e+08, 8.98706443e+08, 5.66756251e+08,
#        1.00363814e+08, 3.10651815e+08, 9.61403794e+07, 2.49214147e+08,
#        7.25660375e+08, 6.07349096e+08, 1.37239378e+08, 7.53399679e+08,
#        3.11321096e+08, 1.63115274e+08, 2.56995490e+08, 3.51892476e+08,
#        8.66421114e+08, 5.78654832e+08, 5.56500578e+08, 1.30595093e+08,
#        3.15563626e+08, 1.49006297e+08, 7.37371813e+08])

# %%
#test데이터 R-square
model.score(x2_test, y1_test) #큰 값을 가진다
# Out:
# 0.985357999638782

# %%
# 예측 vs. 실제데이터 plot
y_pred = model.predict(x2_test) 
plt.plot(y1_test, y_pred, '.')

# 예측과 실제가 비슷하면, 라인상에 분포함
x = np.linspace(0, 3e9, 100)
y = x
plt.plot(x, y)
plt.show()

# %% [markdown]
# 잘 분포해있음!

# %% [markdown]
# # 3. 행렬을 통해 beta와 MSE 구하기

# %%
x = np.array(x2) #3x3
y = np.transpose(np.array(y1)) #3x1

# %%
x #데이터 확인
# Out:
# array([[1.76603730e+09, 2.00000000e+00, 1.00000000e+00, ...,
#         1.00000000e+00, 1.00000000e+00, 0.00000000e+00],
#        [1.52946867e+08, 2.00000000e+00, 1.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.13265100e+07, 3.00000000e+00, 2.00000000e+00, ...,
#         1.00000000e+00, 0.00000000e+00, 1.00000000e+00],
#        ...,
#        [3.54805459e+08, 2.00000000e+00, 1.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00],
#        [8.00000000e+07, 2.00000000e+00, 1.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00],
#        [1.80000000e+08, 2.00000000e+00, 1.00000000e+00, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00]])

# %%
y
# Out:
# array([ 760000000,  971889999,   93399999, ..., 1118999990,  403000000,
#         686010000], dtype=int64)

# %%
estimate_beta(x,y)
# Out:
# array([ 4.58941154e-03, -1.34186609e+07,  3.26637589e+07,  2.44945488e+01,
#        -2.78289284e+05,  3.48610648e-02,  1.09248838e+00,  2.82059100e+05,
#        -3.62203418e+05, -8.43905365e+06,  1.88269709e+07, -5.46568286e+06,
#         8.39898246e+06,  1.06241316e+07])

# %%
#앞의 문제에서 구한 값과 비교하면
print(model.coef_)
print(model.intercept_)
# Out:
# [ 4.41179231e-03 -1.73437140e+07  3.72960230e+07  2.24587054e+01
#  -3.18434532e+05  4.29484622e-02  1.08304488e+00  2.89081600e+05
#  -7.63635984e+05 -1.20784289e+07 -3.91724282e+07 -6.32196199e+07
#  -7.40050019e+06 -2.24982924e+06]
# 85127353.16815108

# %% [markdown]
# 완전히 일치한다고는 할 수 없지만, 몇몇 값을 제외하고는 비슷한 값을 가짐을 확인할 수 있음.
